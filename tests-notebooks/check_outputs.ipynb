# %%
from handlers import files_handler as fh
from handlers import image_handler
from handlers import label_handler
import pandas as pd
import numpy as np
import random
from skimage import io
from utils import utils
import matplotlib.pyplot as plt
from utils.consts import *

# %%
img_name = "e06585e6-7e50-45a4-80d7-4a9154677063"
image = io.imread(fh.get_output_img_path(img_name), as_gray=True)
label_v1 = np.load(fh.get_output_label_path_v1(img_name))
label_v2 = np.load(fh.get_output_label_path_v2(img_name))

# %%
utils.show_image(image, title="SYNTHESIZED IMAGE", save=False)

# %%
utils.show_image(label_v1[0, :, :], title="BACKGROUND v1", save=False)

# %%
utils.show_image(label_v1[1, :, :], title="LAYER_1 v1", save=False)

# %%
utils.show_image(label_v1[2, :, :], title="LAYER_2 v1", save=False)

# %%
utils.show_image(label_v2[0, :, :], title="BACKGROUND v2", save=False)

# %%
utils.show_image(label_v2[1, :, :], title="LAYER_1 v2", save=False)

# %%
utils.show_image(label_v2[2, :, :], title="LAYER_2 v2", save=False)

# %%
utils.show_image(label_v2[3, :, :], title="BOTH v2", save=False)
